# %% [markdown]
# # Labs main
#
# ## lab 1
# **basics, introduction, data loading & cleaning**
#
# Should we do a quick start with:
# - [python repetition (optional)](lab01_03_python_repetition.ipynb)
#
# Otherwise, let's dive directly.
# Some small exercises are included. Take 3-5 mins for each one trying to figure it out.
# Then, we will together work out a solution.
#
# - [basics](lab01_01basics.ipynb)
# - [pandas exercise 1](lab01_03_pandas_exercise.ipynb)
# - [pandas walk through larger data set (1)](lab01_03SelectingDataAndFindingTheMostCommonComplaintType_class.ipynb)
# - [pandas walk through larger data set (2)](lab01_03_value_counts_complaints.ipynb)
# - [pandas walk through larger data set (3)](lab01_03_CleaningUp.ipynb)
# - [time series](lab01_03_time_series.ipynb)
# - [data visualization using seaborn](lab01_03_seaborn_vis.ipynb)
#
# Many more topics could be covered (Images, Video, Social Networks(Graphs), Text, Audio), unfortunately, this is not possible due to time constraints.
#
# After giving you a basic toolkit now for the rest of the day - 90 minutes you should apply this toolkit on your own dataset. For the last 90 minutes half of the groups will give a short presentation.
#
# Your task:
# - [data set assignment](lab01_04_dataset_assignment.ipynb)
#
# ## lab 2
# **ML modeling, cross validation, model evaluation**
#
# Again, we will walk through some basics togehter and I will hand you a tookit full of AI & ML.
#
# - [ml introduction scikit-learn](lab2_1-Introducing-Scikit-Learn.ipynb)
# - [hyper parameters & model validation](lab2_2-Hyperparameters-and-Model-Validation.ipynb)
# - [feature engineering](lab2_3-Feature-Engineering.ipynb)
# - [tree based models](lab2_6-tree-based-models.ipynb)
# - [explanable AI](lab2_7-explainableAI.ipynb)
# - [optional deep learning example fast AI bascis - pet classification](lab2_8_dl_basics-pets.ipynb)
# - [optional deep learning embeddings on tabular data](lab2_9_dl_tabular.ipynb)
#
#
# Continue with your own data for 1 hour. Apply the techniques.
# No presentations just yet.
#
# Tasks:
# - choose a ML task suitable for your data:
#     - regression
#     - classification
#     - clustering
#     - anomaly detection
# - choose a metric to evaluate performance
# - evaluate performance, also perform supervised evaluation using cross validation
# - explain some of the best and worst predictions using an explanability framework. Try to understand why. Showcase this also in the presentation.
# - fit multiple models and compare the results
#     - Dummy classifier
#     - simple model
#     - tree based model
#     - whatever you like model
# - tune hyper parameters
#     - by hand
#     - in some automated way (random, grid search, bayesian)
#
# ## lab 3
# **deployment of ML as API & governance**
#
# - [automate the boring stuff](lab3_01.ipynb)
# - [governance, repeatability: mlflow, API & CI](lab3_02.ipynb)
# - [optional monitoring & E2E example](lab3_03.ipynb)
#
# Now you can apply this knowledge again.
#
# - only using reproducible ML artifacts via i.e. mlFlow is enough here
# - but do demonstrate that you can generate a minimalistic API
# - and can query it
#
# Continue for the rest of the time until 90 minutes are left.
# This time the other half will present what they achieved in a similar setup, but the content shall cover lab 2 and 3.
